# %%
import pandas as pd
import numpy as np

INPUT_JSON_FILE = 'questions.json'

pd.set_option('display.max_colwidth', -1)
df = pd.read_json(INPUT_JSON_FILE).drop("short_description", 1).drop("tag", 1)
df = df.sort_values(['answers', 'votes', 'views'], ascending=[True, False, False])
df
# Out:
#     answers  \
# 39  0
# 49  0
# 12  0
# 7   0
# 43  0
# 3   0
# 29  0
# 36  0
# 32  0
# 14  0
# 41  0
# 19  0
# 27  0
# 35  0
# 38  0
# 20  0
# 22  0
# 2   0
# 15  0
# 23  0
# 25  0
# 44  0
# 40  0
# 6   0
# 8   0
# 10  0
# 5   0
# 47  0
# 13  0
# 45  0
# 30  0
# 9   0
# 0   0
# 17  0
# 24  0
# 11  0
# 16  1
# 26  1
# 37  1
# 28  1
# 18  1
# 34  1
# 46  1
# 1   1
# 48  1
# 21  2
# 33  2
# 42  2
# 4   2
# 31  5
#
#                                                                                                   title  \
# 39  scipy.signal.resample: malfunction with even number of points?
# 49  How do I plot a histogram of months with dates in matplotlib
# 12  Python array counter
# 7   'float' object has no attribute '__getitem__' in for loop
# 43  Incorrectly returning the value of a Node at position 'm' in a linked list
# 3   Python- Labeling items in a list by year
# 29  Python scriptline to get date&time
# 36  define 2 GET ABSOLUTE URL method
# 32  Spectrogram of a wave file
# 14  Tkinter threading and return to text widget
# 41  Python Bokeh - Assign taptool to a subset of Glyphs
# 19  plot_time and annoying “.f” in x-axis
# 27  Django - Redirecting after ajax post call with the data
# 35  Run all the code in a Django ModelForm __init__() method after an invalid form submission
# 38  Using python's pysftp, how do you generate a host key?
# 20  How can I avoid tox from reinstalling dependencies and deleting my break point?
# 22  Get function name as script parameter [duplicate]
# 2   Require help understanding Flask url_for()
# 15  Python, evdev, usb barcode reader: how to decode the input data
# 23  Carmen-Python: the JSON object must be str, not 'bytes'
# 25  PyCharm - Expected type 'Optional[IO[str]]', got 'TextIOWrapper[str]' instead
# 44  Stabilizing an Already Seeded Tensorflow Network and Predicting Confidence
# 40  Trouble importing from rpy2.robjects
# 6   Reshape batch of tensors into batch of vectors in TensorFlow
# 8   Error loading MySQLdb module:_mysql.so: undefined symbol: mysql_shutdown
# 10  cartToPolar in openCV gives only degrees between 0 and 90
# 5   How to use a Python weakref cache mapping keys to values, when values hold a reference to the keys?
# 47  add python as a CGI on a apache/php5-fpm enabled debian server
# 13  Why this script won't work if the while is set to true?
# 45  How to create an object from a class— getting an Attribute error
# 30  sklearn - knn sklearn.neighbors kneighbors function producing unexpected result for text analysis?
# 9   Check if geo coordinate point is land or ocean
# 0   Summing multiple dictionary values from a generator expression
# 17  Why does python put a namespace here? [on hold]
# 24  How to debug “TypeError: 'NoneType' object has no attribute '__getitem__'”?
# 11  Python Sync Task [on hold]
# 16  Beautiful Soup: Data Values Not Matching Headings
# 26  Interpolating climate data with irregular measurement intervals in Python with pandas and traces
# 37  Dynamically adding elements to a NumPy array of unknown final length
# 28  Issues installing pynini
# 18  Spark structured streaming with python
# 34  What does this mean: “unable to send message, socket is not open”?
# 46  Change range withouth scaling in matplot
# 1   Spyder changes working directory (wdir) when running a script
# 48  Python ViolinPlots
# 21  How to compute volatility (standard deviation) in rolling window in Pandas
# 33  Python loop - help me understand
# 13  https://stackoverflow.com/questions/tagged/python/questions/43284486/why-this-script-wont-work-if-the-while-is-set-to-true
# 45  https://stackoverflow.com/questions/tagged/python/questions/43283657/how-to-create-an-object-from-a-class-getting-an-attribute-error
# 30  https://stackoverflow.com/questions/tagged/python/questions/43284115/sklearn-knn-sklearn-neighbors-kneighbors-function-producing-unexpected-result
# 9   https://stackoverflow.com/questions/tagged/python/questions/43284606/check-if-geo-coordinate-point-is-land-or-ocean
# 0   https://stackoverflow.com/questions/tagged/python/questions/43284804/summing-multiple-dictionary-values-from-a-generator-expression
# 17  https://stackoverflow.com/questions/tagged/python/questions/43284383/why-does-python-put-a-namespace-here
# 24  https://stackoverflow.com/questions/tagged/python/questions/43284280/how-to-debug-typeerror-nonetype-object-has-no-attribute-getitem
# 11  https://stackoverflow.com/questions/tagged/python/questions/43284529/python-sync-task
# 16  https://stackoverflow.com/questions/tagged/python/questions/43284399/beautiful-soup-data-values-not-matching-headings
# 26  https://stackoverflow.com/questions/tagged/python/questions/43284165/interpolating-climate-data-with-irregular-measurement-intervals-in-python-with-p
# 37  https://stackoverflow.com/questions/tagged/python/questions/43283866/dynamically-adding-elements-to-a-numpy-array-of-unknown-final-length
# 28  https://stackoverflow.com/questions/tagged/python/questions/43284123/issues-installing-pynini
# 18  https://stackoverflow.com/questions/tagged/python/questions/43284380/spark-structured-streaming-with-python
# 34  https://stackoverflow.com/questions/tagged/python/questions/43283951/what-does-this-mean-unable-to-send-message-socket-is-not-open
# 46  https://stackoverflow.com/questions/tagged/python/questions/43283643/change-range-withouth-scaling-in-matplot
# 1   https://stackoverflow.com/questions/tagged/python/questions/43284787/spyder-changes-working-directory-wdir-when-running-a-script
# 48  https://stackoverflow.com/questions/tagged/python/questions/43283599/python-violinplots
# 21  https://stackoverflow.com/questions/tagged/python/questions/43284304/how-to-compute-volatility-standard-deviation-in-rolling-window-in-pandas
# 33  https://stackoverflow.com/questions/tagged/python/questions/43283960/python-loop-help-me-understand
# 42  https://stackoverflow.com/questions/tagged/python/questions/43283714/run-python-script-from-cmd-with-inputs
# 4   https://stackoverflow.com/questions/tagged/python/questions/43284717/which-sparse-matrix-representation-to-use-with-sklearn-svm-linearsvc
# 31  https://stackoverflow.com/questions/tagged/python/questions/43284071/how-to-take-all-the-words-in-a-list-element-as-a-variable
#
#     views  votes
# 39  14     1
# 49  9      1
# 12  46     0
# 7   33     0
# 43  26     0
# 3   23     0
# 29  18     0
# 36  16     0
# 32  15     0
# 14  13     0
# 41  13     0
# 19  12     0
# 27  12     0
# 35  12     0
# 38  12     0
# 20  11     0
# 22  10     0
# 2   9      0
# 15  9      0
# 23  9      0
# 25  9      0
# 44  8      0
# 40  7      0
# 6   6      0
# 8   6      0
# 10  5      0
# 5   4      0
# 47  4      0
# 13  28    -1
# 45  22    -1
# 30  16    -1
# 9   12    -1
# 0   19    -2
# 17  17    -2
# 24  25    -3
# 11  24    -7
# 16  16     1
# 26  28     0
# 37  26     0
# 28  15     0
# 18  14     0
# 34  13     0
# 46  13     0
# 1   4      0
# 48  17    -1
# 21  39     1
# 33  26     0
# 42  23     0
# 4   6      0
# 31  47     0
