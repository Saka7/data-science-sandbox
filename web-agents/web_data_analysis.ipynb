# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

INPUT_JSON_FILE = 'questions.json'
plt.style.use("ggplot")

pd.set_option('display.max_colwidth', -1)
df = pd.read_json(INPUT_JSON_FILE).drop("short_description", 1).drop("tag", 1)
df = df.sort_values(['answers', 'votes', 'views'], ascending=[True, False, False])
df.plot.scatter(x="views", y="votes")
df.plot.scatter(x="views", y="answers")
df.plot.scatter(x="answers", y="votes")
plt.show()
df
# Out:
#     answers  \
# 23  0
# 15  0
# 33  0
# 25  0
# 31  0
# 42  0
# 19  0
# 32  0
# 22  0
# 2   0
# 49  0
# 1   0
# 30  0
# 12  0
# 20  0
# 28  0
# 8   0
# 47  0
# 13  0
# 10  0
# 11  0
# 3   0
# 17  0
# 45  0
# 29  0
# 38  0
# 18  0
# 24  0
# 39  0
# 0   0
# 46  0
# 6   0
# 14  0
# 26  0
# 4   1
# 27  1
# 40  1
# 34  1
# 36  1
# 21  1
# 7   1
# 16  2
# 37  2
# 48  2
# 43  2
# 41  2
# 35  2
# 5   2
# 44  4
# 9   5
#
#                                                                                                                      title  \
# 23  Decoding of bytes object results in unexpected + invalid UTF-8 - how can I avoid this?
# 15  Pandas analogue of SQL's “NOT IN” operator
# 33  Split string by number of whitespaces
# 25  PyPDF2 - manually adding new page to merged PDF offsets original bookmark destinations
# 31  Sort a JSON using Python
# 42  Use numpy to translate huge array of 2-byte strings to corresponding 1-byte strings according to a fixed mapping
# 19  Python pandas dataframe convert values without decimals
# 32  Python Selenium Get PageSource of XHTML
# 22  Microsoft Exchange Integration in Python
# 2   Python store line by line in List from Text File
# 49  Type() not detecting my class (Tree) in Python 3
# 1   Python: Trying to loggin with requests and perform a HTTP request
# 30  Google App Engine api throws 503, but error not shown in the admin console
# 12  How to let compiler interpret as bolean context [on hold]
# 20  Python Rotation Matirx Error
# 28  Identifying sublists entirely contained within other lists
# 8   SQLITE Python cannot change value
# 47  Multiple Processing with a loop
# 13  Splitting to make Workbooks
# 10  Can I get IP address and port of disconnected client in Tornado
# 11  repomd.xml missing for epel-release repo
# 3   How to remove specific item and lines from xml?
# 17  insert into table from another table with alembic
# 45  Certificate verification failed with Python 2.7.13 and OpenSSL 1.1.0e on Ubuntu 16.04
# 29  In python, can I write a function within one file that uses the filename of another file which imports it? [duplicate]
# 38  Installing libLAS on docker python - No such file or directory
# 18  Pyqt5 : Error converting .ui file to .py file [on hold]
# 24  Keithley 2410 and PyVISA - VI_ERROR_TMO: Timeout expired before operation completed
# 39  windows 10 virtualenv access denied
# 0   Match specific arrayvalue python
# 46  Multilevel inheritance in python for user inputs
# 6   %d format: a number is required, not NoneType
# 14  JQuery in Python (py File)
# 26  python: reverse them for very two elements in list [duplicate]
# 4   analysing data using R, AWS lambda and python
# 27  Construct YAML that contains JSON data in python
# 40  Tkinter - Returning from a class and calling a new one
# 34  How to give name to each node in celery
# 36  Items movement daily collection database design system issue
# 21  cx_Oracle.DatabaseError: ORA-01858: date time false format
# 7   Extracting data within multiple links using SCRAPY
# 16  Why sorted list_b has no value? [duplicate]
# 37  Python - mutable default arguments to functions
# 48  raspberry pi sending data to a XAMPP database
# 43  Python with MySQL connector, no information being sent to database
# 41  Comparing the order of specific elements in a python list
# 35  How can I add the first line in a text file to following lines until a condition is met then repeat?
# 5   Getting an array from collections ordereddict for the maximum key, values
# 44  Why does np.array([4, 3, 0]) + np.array([0, 2, 2]) give an output of array([4,5,2])
# 9   Compare two lists of tuples
#
#                                                                                                                               url  \
# 23  https://stackoverflow.com/questions/43256079/decoding-of-bytes-object-results-in-unexpected-invalid-utf-8-how-can-i-avoid
# 15  https://stackoverflow.com/questions/43256402/pandas-analogue-of-sqls-not-in-operator
# 33  https://stackoverflow.com/questions/43255850/split-string-by-number-of-whitespaces
# 25  https://stackoverflow.com/questions/43256025/pypdf2-manually-adding-new-page-to-merged-pdf-offsets-original-bookmark-destin
# 31  https://stackoverflow.com/questions/43255909/sort-a-json-using-python
# 42  https://stackoverflow.com/questions/43255679/use-numpy-to-translate-huge-array-of-2-byte-strings-to-corresponding-1-byte-stri
# 19  https://stackoverflow.com/questions/43256211/python-pandas-dataframe-convert-values-without-decimals
# 32  https://stackoverflow.com/questions/43255904/python-selenium-get-pagesource-of-xhtml
# 22  https://stackoverflow.com/questions/43256137/microsoft-exchange-integration-in-python
# 2   https://stackoverflow.com/questions/43256926/python-store-line-by-line-in-list-from-text-file
# 49  https://stackoverflow.com/questions/43255495/type-not-detecting-my-class-tree-in-python-3
# 1   https://stackoverflow.com/questions/43256970/python-trying-to-loggin-with-requests-and-perform-a-http-request
# 30  https://stackoverflow.com/questions/43255910/google-app-engine-api-throws-503-but-error-not-shown-in-the-admin-console
# 12  https://stackoverflow.com/questions/43256479/how-to-let-compiler-interpret-as-bolean-context
# 20  https://stackoverflow.com/questions/43256193/python-rotation-matirx-error
# 28  https://stackoverflow.com/questions/43255995/identifying-sublists-entirely-contained-within-other-lists
# 8   https://stackoverflow.com/questions/43256747/sqlite-python-cannot-change-value
# 47  https://stackoverflow.com/questions/43255525/multiple-processing-with-a-loop
# 13  https://stackoverflow.com/questions/43256475/splitting-to-make-workbooks
# 10  https://stackoverflow.com/questions/43256641/can-i-get-ip-address-and-port-of-disconnected-client-in-tornado
# 11  https://stackoverflow.com/questions/43256563/repomd-xml-missing-for-epel-release-repo
# 3   https://stackoverflow.com/questions/43256911/how-to-remove-specific-item-and-lines-from-xml
# 17  https://stackoverflow.com/questions/43256390/insert-into-table-from-another-table-with-alembic
# 45  https://stackoverflow.com/questions/43255589/certificate-verification-failed-with-python-2-7-13-and-openssl-1-1-0e-on-ubuntu
# 29  https://stackoverflow.com/questions/43255967/in-python-can-i-write-a-function-within-one-file-that-uses-the-filename-of-anot
# 38  https://stackoverflow.com/questions/43255751/installing-liblas-on-docker-python-no-such-file-or-directory
# 18  https://stackoverflow.com/questions/43256380/pyqt5-error-converting-ui-file-to-py-file
# 24  https://stackoverflow.com/questions/43256071/keithley-2410-and-pyvisa-vi-error-tmo-timeout-expired-before-operation-comple
# 39  https://stackoverflow.com/questions/43255735/windows-10-virtualenv-access-denied
# 0   https://stackoverflow.com/questions/43257047/match-specific-arrayvalue-python
# 46  https://stackoverflow.com/questions/43255536/multilevel-inheritance-in-python-for-user-inputs
# 6   https://stackoverflow.com/questions/43256779/d-format-a-number-is-required-not-nonetype
# 14  https://stackoverflow.com/questions/43256456/jquery-in-python-py-file
# 26  https://stackoverflow.com/questions/43256015/python-reverse-them-for-very-two-elements-in-list
# 4   https://stackoverflow.com/questions/43256863/analysing-data-using-r-aws-lambda-and-python
# 27  https://stackoverflow.com/questions/43256007/construct-yaml-that-contains-json-data-in-python
# 40  https://stackoverflow.com/questions/43255710/tkinter-returning-from-a-class-and-calling-a-new-one
# 34  https://stackoverflow.com/questions/43255831/how-to-give-name-to-each-node-in-celery
# 36  https://stackoverflow.com/questions/43255792/items-movement-daily-collection-database-design-system-issue
# 21  https://stackoverflow.com/questions/43256153/cx-oracle-databaseerror-ora-01858-date-time-false-format
# 7   https://stackoverflow.com/questions/43256758/extracting-data-within-multiple-links-using-scrapy
# 16  https://stackoverflow.com/questions/43256396/why-sorted-list-b-has-no-value
# 37  https://stackoverflow.com/questions/43255782/python-mutable-default-arguments-to-functions
# 48  https://stackoverflow.com/questions/43255524/raspberry-pi-sending-data-to-a-xampp-database
# 43  https://stackoverflow.com/questions/43255643/python-with-mysql-connector-no-information-being-sent-to-database
# 41  https://stackoverflow.com/questions/43255697/comparing-the-order-of-specific-elements-in-a-python-list
# 35  https://stackoverflow.com/questions/43255808/how-can-i-add-the-first-line-in-a-text-file-to-following-lines-until-a-condition
# 5   https://stackoverflow.com/questions/43256822/getting-an-array-from-collections-ordereddict-for-the-maximum-key-values
# 44  https://stackoverflow.com/questions/43255628/why-does-np-array4-3-0-np-array0-2-2-give-an-output-of-array4-5
# 9   https://stackoverflow.com/questions/43256677/compare-two-lists-of-tuples
#
#     views  votes
# 23  49     3
# 15  31     3
# 33  42     2
# 25  20     2
# 31  55     1
# 42  41     1
# 19  20     1
# 32  14     1
# 22  13     1
# 2   31     0
# 49  31     0
# 1   30     0
# 30  29     0
# 12  27     0
# 20  26     0
# 28  22     0
# 8   20     0
# 47  20     0
# 13  18     0
# 10  16     0
# 11  16     0
# 3   15     0
# 17  15     0
# 45  15     0
# 29  14     0
# 38  12     0
# 18  7      0
# 24  7      0
# 39  7      0
# 0   24    -1
# 46  16    -1
# 6   33    -2
# 14  9     -3
# 26  23    -5
# 4   30     1
# 27  25     0
# 40  24     0
# 34  11     0
# 36  10     0
# 21  6      0
# 7   30    -1
# 16  35     0
# 37  14     0
# 48  13     0
# 43  9      0
# 41  83    -1
# 35  26    -1
# 5   22    -1
# 44  44    -5
# 9   56     2
